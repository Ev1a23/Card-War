# %%
import random

# %%
#A dictonary to store every card score
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 
            'Nine':9, 'Ten':10, 'Jack':11, 'Queen':12, 'King':13, 'Ace':14}

# %%
#A tuple to store which kinds of suits a card can have
suits = ('Hearts','Diamonds', 'Spades', 'Clubs')

# %%
#A tuple to store which kinds of rank a card can have
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')

# %%
#Class to define a card
class Card:
    
    def __init__(self,suit,rank):
        self.suit = str(suit).capitalize()
        self.rank = str(rank).capitalize()
        self.value = values[rank]
        
    def __str__(self):
        return (self.rank + ' of ' + self.suit)

# %%
two_hearts = Card('Hearts', 'Two')
two_hearts

# %%
print(two_hearts)
# Out:
# Two of Hearts

# %%
two_hearts.suit
# Out:
# 'Hearts'

# %%
two_hearts.rank
# Out:
# 'Two'

# %%
two_hearts.value
# Out:
# 2

# %%
three_clubs = Card('Clubs', 'Three')

# %%
two_hearts.value < three_clubs.value
# Out:
# True

# %%
#Class to define a game deck
class Deck:
    
    def __init__(self):
        self.all_cards = [] #list to store all the cards in the game
        for suit in suits:
            for rank in ranks:
                created_card = Card(suit,rank)
                self.all_cards.append(created_card)
    
    #Method to shuffle the deck
    def shuffle(self):
        random.shuffle(self.all_cards)
    
    #Method to deal one card of the deck
    def deal_one(self):
        return self.all_cards.pop(0)

# %%
new_deck = Deck()

# %%
for card in new_deck.all_cards:
    print(card)
# Out:
# Two of Hearts
# Three of Hearts
# Four of Hearts
# Five of Hearts
# Six of Hearts
# Seven of Hearts
# Eight of Hearts
# Nine of Hearts
# Ten of Hearts
# Jack of Hearts
# Queen of Hearts
# King of Hearts
# Ace of Hearts
# Two of Diamonds
# Three of Diamonds
# Four of Diamonds
# Five of Diamonds
# Six of Diamonds
# Seven of Diamonds
# Eight of Diamonds
# Nine of Diamonds
# Ten of Diamonds
# Jack of Diamonds
# Queen of Diamonds
# King of Diamonds
# Ace of Diamonds
# Two of Spades
# Three of Spades
# Four of Spades
# Five of Spades
# Six of Spades
# Seven of Spades
# Eight of Spades
# Nine of Spades
# Ten of Spades
# Jack of Spades
# Queen of Spades
# King of Spades
# Ace of Spades
# Two of Clubs
# Three of Clubs
# Four of Clubs
# Five of Clubs
# Six of Clubs
# Seven of Clubs
# Eight of Clubs
# Nine of Clubs
# Ten of Clubs
# Jack of Clubs
# Queen of Clubs
# King of Clubs
# Ace of Clubs

# %%
new_deck.shuffle()
for card in new_deck.all_cards:
    print(card)
# Out:
# Ace of Clubs
# Two of Clubs
# Jack of Spades
# Four of Hearts
# Nine of Hearts
# Five of Clubs
# Two of Spades
# Six of Diamonds
# Queen of Hearts
# Seven of Hearts
# Nine of Diamonds
# Jack of Diamonds
# Ten of Hearts
# Seven of Spades
# Queen of Clubs
# Four of Diamonds
# Nine of Spades
# King of Spades
# Jack of Clubs
# Three of Clubs
# King of Diamonds
# Four of Spades
# Four of Clubs
# Three of Hearts
# Five of Diamonds
# Ace of Hearts
# Queen of Diamonds
# Eight of Diamonds
# King of Hearts
# Five of Hearts
# Three of Spades
# Seven of Diamonds
# Three of Diamonds
# Eight of Hearts
# Ten of Diamonds
# Eight of Clubs
# Ten of Spades
# Eight of Spades
# Six of Hearts
# Six of Clubs
# Two of Hearts
# Ace of Spades
# Six of Spades
# Ace of Diamonds
# King of Clubs
# Seven of Clubs
# Ten of Clubs
# Queen of Spades
# Nine of Clubs
# Jack of Hearts
# Five of Spades
# Two of Diamonds

# %%
card1 = new_deck.deal_one()
print(card1)
print(len(new_deck.all_cards))
# Out:
# Ace of Clubs
# 51

# %%
#Class to define a player in the gmae
class Player:
    
    def __init__(self,name):
        self.name = name
        self.all_cards = []
    
    #Method to remove the top card of the list of cards that a player have
    def remove_one(self):
        return self.all_cards.pop(0)
    
    #Method to add one card/multiple cards to the list of cards that a player have
    def add_cards(self,new_cards):
        if(type(new_cards) == type([])):
            self.all_cards.extend(new_cards)
        else:
            self.all_cards.append(new_cards)
    
    def __str__ (self):
        if(len(self.all_cards) != 1):
            return(f'Player {self.name} Has {len(self.all_cards)} Cards')
        else:
            return(f'Player {self.name} Has 1 Card')

# %%
player1 = Player('Eviatar')

# %%
player1.add_cards([three_clubs,two_hearts])

# %%
print(player1)
player1.remove_one()
print(player1)
# Out:
# Player Eviatar Has 2 Cards
# Player Eviatar Has 1 Card

# %%
#Game Setup
p1 = Player('One')
p2 = Player('Two')
game_deck = Deck()
game_deck.shuffle()
#Divide the cards between the players
for x in range(26):
        p1.add_cards(game_deck.deal_one())
        p2.add_cards(game_deck.deal_one())
print(p1.all_cards[0])
print(p2.all_cards[0])
#Boolean to store if the game should be played
game_on=True
#Counter to keep track of which round is it
round_num = 0
#Bollean to get into checking the cards of each player, if there values aren't equal, it'll change to False and exit the loop, else it will stay True
at_war = True
# Out:
# Eight of Clubs
# Jack of Clubs

# %%
#Actual Game
while game_on:
    round_num +=1
    print(f'Round {round_num}')
    if len(p1.all_cards) == 0:
        print(f'Player {p1.name} Is Out Of Cards, Player {p2.name} Wins!')
        game_on = False
        break
    
    if len(p2.all_cards) == 0:
        print(f'Player {p2.name} Is Out Of Cards, Player {p1.name} Wins!')
        game_on = False
        break
    
    p1_cards = []
    p1_cards.append(p1.remove_one())
    p2_cards = []
    p2_cards.append(p2.remove_one())
    
    at_war = True
    while at_war:
        print(f'Player {p1.name} card: {p1_cards[-1]}, Player {p2.name} card: {p2_cards[-1]} ')
        if p1_cards[-1].value > p2_cards[-1].value:
            p1.add_cards(p1_cards)
            p1.add_cards(p2_cards)
            at_war = False
        elif(p1_cards[-1].value < p2_cards[-1].value):
            p2.add_cards(p2_cards)
            p2.add_cards(p1_cards)
            at_war = False
        else:
            print('WAR!')
            
            #To shorten a bit the game, if a player can't draw a card on a war, he loses immediately, and on a war each needs to draw 5 cards instead of 3 on the original game
            if(len(p1.all_cards)<5):
                print(f'Player {p1.name} Unable To Declare War')
                print(f'Player {p2.name} Wins!')
                game_on = False
                break
            elif(len(p2.all_cards)<5):
                print(f'Player {p2.name} Unable To Declare War')
                print(f'Player {p1.name} Wins!')
                game_on = False
                break
            else:
                for num in range(5):
                    p1_cards.append(p1.remove_one())
                    p2_cards.append(p2.remove_one())
# Out:
# Round 1
# Player One card: Eight of Clubs, Player Two card: Jack of Clubs
# Round 2
# Player One card: Ace of Diamonds, Player Two card: Nine of Diamonds
# Round 3
# Player One card: Five of Clubs, Player Two card: King of Spades
# Round 4
# Player One card: Jack of Hearts, Player Two card: Two of Hearts
# Round 5
# Player One card: Eight of Diamonds, Player Two card: Ace of Hearts
# Round 6
# Player One card: Three of Spades, Player Two card: Eight of Spades
# Round 7
# Player One card: Queen of Spades, Player Two card: Seven of Spades
# Round 8
# Player One card: Two of Spades, Player Two card: Nine of Spades
# Round 9
# Player One card: Three of Hearts, Player Two card: Four of Spades
# Round 10
# Player One card: Ten of Hearts, Player Two card: Nine of Clubs
# Round 11
# Player One card: King of Hearts, Player Two card: Three of Diamonds
# Round 12
# Player One card: Ace of Spades, Player Two card: Eight of Hearts
# Round 13
# Player One card: King of Clubs, Player Two card: Four of Diamonds
# Round 14
# Player One card: Six of Diamonds, Player Two card: Four of Hearts
# Round 15
# Player One card: Three of Clubs, Player Two card: Ace of Clubs
# Round 16
# Player One card: Six of Hearts, Player Two card: King of Diamonds
# Round 17
# Player One card: Five of Diamonds, Player Two card: Two of Clubs
# Round 18
# Player One card: Ten of Clubs, Player Two card: Seven of Diamonds
# Round 19
# Player One card: Jack of Spades, Player Two card: Ten of Diamonds
# Round 20
# Player One card: Two of Diamonds, Player Two card: Queen of Clubs
# Round 21
# Player One card: Five of Hearts, Player Two card: Four of Clubs
# Round 22
# Player One card: Seven of Hearts, Player Two card: Ten of Spades
# Round 23
# Player One card: Queen of Hearts, Player Two card: Six of Clubs
# Round 24
# Player One card: Five of Spades, Player Two card: Seven of Clubs
# Round 25
# Player One card: Jack of Diamonds, Player Two card: Queen of Diamonds
# Round 26
# Player One card: Six of Spades, Player Two card: Nine of Hearts
# Round 27
# Player One card: Ace of Diamonds, Player Two card: Jack of Clubs
# Round 28
# Player One card: Nine of Diamonds, Player Two card: Eight of Clubs
# Round 29
# Player One card: Jack of Hearts, Player Two card: King of Spades
# Round 30
# Player One card: Two of Hearts, Player Two card: Five of Clubs
# Round 31
# Player One card: Queen of Spades, Player Two card: Ace of Hearts
# Round 32
# Player One card: Seven of Spades, Player Two card: Eight of Diamonds
# Round 33
# Player One card: Ten of Hearts, Player Two card: Eight of Spades
# Round 34
# Player One card: Nine of Clubs, Player Two card: Three of Spades
# Round 35
# Player One card: King of Hearts, Player Two card: Nine of Spades
# Round 36
# Player One card: Three of Diamonds, Player Two card: Two of Spades
# Round 37
# Player One card: Ace of Spades, Player Two card: Four of Spades
# Round 38
# Player One card: Eight of Hearts, Player Two card: Three of Hearts
# Round 39
# Player One card: King of Clubs, Player Two card: Ace of Clubs
# Round 40
# Player One card: Four of Diamonds, Player Two card: Three of Clubs
# Round 41
# Player One card: Six of Diamonds, Player Two card: King of Diamonds
# Round 42
# Player One card: Four of Hearts, Player Two card: Six of Hearts
# Round 43
# Player One card: Five of Diamonds, Player Two card: Queen of Clubs
# Round 44
# Player One card: Two of Clubs, Player Two card: Two of Diamonds
# WAR!
# Player One card: Five of Hearts, Player Two card: Queen of Diamonds
# Round 45
# Player One card: Four of Clubs, Player Two card: Jack of Diamonds
# Round 46
# Player One card: Queen of Hearts, Player Two card: Nine of Hearts
# Round 47
# Player One card: Six of Clubs, Player Two card: Six of Spades
# WAR!
# Player One card: Ten of Hearts, Player Two card: Ace of Hearts
# Round 48
# Player One card: Eight of Spades, Player Two card: Queen of Spades
# Round 49
# Player One card: Nine of Clubs, Player Two card: Eight of Diamonds
# Round 50
# Player One card: Three of Spades, Player Two card: Seven of Spades
# Round 51
# Player One card: King of Hearts, Player Two card: Ace of Clubs
# Round 52
# Player One card: Nine of Spades, Player Two card: King of Clubs
# Round 53
# Player One card: Three of Diamonds, Player Two card: King of Diamonds
# Round 54
# Player One card: Two of Spades, Player Two card: Six of Diamonds
# Round 55
# Player One card: Ace of Spades, Player Two card: Six of Hearts
# Round 56
# Player One card: Four of Spades, Player Two card: Four of Hearts
# WAR!
# Player One card: Queen of Hearts, Player Two card: Seven of Hearts
# Round 57
# Player One card: Nine of Hearts, Player Two card: Seven of Clubs
# Round 58
# Player One card: Nine of Clubs, Player Two card: Five of Spades
# Round 59
# Player One card: Eight of Diamonds, Player Two card: Queen of Diamonds
# Round 60
# Player One card: Ace of Spades, Player Two card: Two of Clubs
# Round 61
# Player One card: Six of Hearts, Player Two card: Ten of Clubs
# Round 62
# Player One card: Four of Spades, Player Two card: Seven of Diamonds
# Round 63
# Player One card: Eight of Hearts, Player Two card: Jack of Spades
# Round 64
# Player One card: Three of Hearts, Player Two card: Ten of Diamonds
# Round 65
# Player One card: Four of Diamonds, Player Two card: Five of Hearts
# Round 66
# Player One card: Three of Clubs, Player Two card: Jack of Diamonds
# Round 67
# Player One card: Queen of Hearts, Player Two card: Four of Clubs
# Round 68
# Player One card: Four of Hearts, Player Two card: Six of Spades
# Round 69
# Player One card: Queen of Clubs, Player Two card: King of Spades
# Round 70
# Player One card: Five of Diamonds, Player Two card: Jack of Hearts
# Round 71
# Player One card: Two of Diamonds, Player Two card: Five of Clubs
# Round 72
# Player One card: Ten of Spades, Player Two card: Two of Hearts
# Round 73
# Player One card: Seven of Hearts, Player Two card: Ace of Hearts
# Round 74
# Player One card: Nine of Hearts, Player Two card: Six of Clubs
# Round 75
# Player One card: Seven of Clubs, Player Two card: Ace of Diamonds
# Round 76
# Player One card: Nine of Clubs, Player Two card: Jack of Clubs
# Round 77
# Player One card: Five of Spades, Player Two card: Nine of Diamonds
# Round 78
# Player One card: Ace of Spades, Player Two card: Eight of Clubs
# Round 79
# Player One card: Two of Clubs, Player Two card: Ten of Hearts
# Round 80
# Player One card: Queen of Hearts, Player Two card: Queen of Spades
# WAR!
# Player One card: Six of Clubs, Player Two card: King of Hearts
# Round 81
# Player One card: Ace of Spades, Player Two card: King of Clubs
# Round 82
# Player One card: Eight of Clubs, Player Two card: Nine of Spades
# Round 83
# Player One card: Ace of Spades, Player Two card: King of Diamonds
# Round 84
# Player One card: King of Clubs, Player Two card: Three of Diamonds
# Round 85
# Player One card: Ace of Spades, Player Two card: Six of Diamonds
# Round 86
# Player One card: King of Diamonds, Player Two card: Two of Spades
# Round 87
# Player One card: King of Clubs, Player Two card: Queen of Diamonds
# Round 88
# Player One card: Three of Diamonds, Player Two card: Eight of Diamonds
# Round 89
# Player One card: Ace of Spades, Player Two card: Ten of Clubs
# Round 90
# Player One card: Six of Diamonds, Player Two card: Six of Hearts
# WAR!
# Player One card: Ace of Spades, Player Two card: Ten of Diamonds
# Round 91
# Player One card: Ten of Clubs, Player Two card: Three of Hearts
# Round 92
# Player One card: Six of Diamonds, Player Two card: Five of Hearts
# Round 93
# Player One card: King of Diamonds, Player Two card: Four of Diamonds
# Round 94
# Player One card: Two of Spades, Player Two card: Jack of Diamonds
# Round 95
# Player One card: King of Clubs, Player Two card: Three of Clubs
# Round 96
# Player One card: Queen of Diamonds, Player Two card: Six of Spades
# Round 97
# Player One card: Ace of Spades, Player Two card: Four of Hearts
# Round 98
# Player One card: Six of Hearts, Player Two card: King of Spades
# Round 99
# Player One card: Seven of Diamonds, Player Two card: Queen of Clubs
# Round 100
# Player One card: Four of Spades, Player Two card: Jack of Hearts
# Round 101
# Player One card: Jack of Spades, Player Two card: Five of Diamonds
# Round 102
# Player One card: Eight of Hearts, Player Two card: Five of Clubs
# Round 103
# Player One card: Ten of Diamonds, Player Two card: Two of Diamonds
# Round 104
# Player One card: Ten of Clubs, Player Two card: Ace of Hearts
# Round 105
# Player One card: Three of Hearts, Player Two card: Seven of Hearts
# Round 106
# Player One card: Six of Diamonds, Player Two card: Ace of Diamonds
# Round 107
# Player One card: Five of Hearts, Player Two card: Seven of Clubs
# Round 108
# Player One card: King of Diamonds, Player Two card: Jack of Clubs
# Round 109
# Player One card: Four of Diamonds, Player Two card: Nine of Clubs
# Round 110
# Player One card: King of Clubs, Player Two card: Nine of Diamonds
# Round 111
# Player One card: Three of Clubs, Player Two card: Five of Spades
# Round 112
# Player One card: Queen of Diamonds, Player Two card: Ten of Hearts
# Round 113
# Player One card: Six of Spades, Player Two card: Two of Clubs
# Round 114
# Player One card: Ace of Spades, Player Two card: Queen of Spades
# Round 115
# Player One card: Four of Hearts, Player Two card: Eight of Spades
# Round 116
# Player One card: Jack of Spades, Player Two card: Seven of Spades
# Round 117
# Player One card: Five of Diamonds, Player Two card: Three of Spades
# Round 118
# Player One card: Eight of Hearts, Player Two card: Ace of Clubs
# Round 119
# Player One card: Five of Clubs, Player Two card: King of Hearts
# Round 120
# Player One card: Ten of Diamonds, Player Two card: Queen of Hearts
# Round 121
# Player One card: Two of Diamonds, Player Two card: Four of Clubs
# Round 122
# Player One card: King of Diamonds, Player Two card: Ten of Spades
# Round 123
# Player One card: Jack of Clubs, Player Two card: Two of Hearts
# Round 124
# Player One card: King of Clubs, Player Two card: Nine of Hearts
# Round 125
# Player One card: Nine of Diamonds, Player Two card: Six of Clubs
# Round 126
# Player One card: Queen of Diamonds, Player Two card: Nine of Spades
# Round 127
# Player One card: Ten of Hearts, Player Two card: Eight of Clubs
# Round 128
# Player One card: Six of Spades, Player Two card: Eight of Diamonds
# Round 129
# Player One card: Two of Clubs, Player Two card: Three of Diamonds
# Round 130
# Player One card: Ace of Spades, Player Two card: Jack of Diamonds
# Round 131
# Player One card: Queen of Spades, Player Two card: Two of Spades
# Round 132
# Player One card: Jack of Spades, Player Two card: King of Spades
# Round 133
# Player One card: Seven of Spades, Player Two card: Six of Hearts
# Round 134
# Player One card: Five of Diamonds, Player Two card: Queen of Clubs
# Round 135
# Player One card: Three of Spades, Player Two card: Seven of Diamonds
# Round 136
# Player One card: King of Diamonds, Player Two card: Jack of Hearts
# Round 137
# Player One card: Ten of Spades, Player Two card: Four of Spades
# Round 138
# Player One card: Jack of Clubs, Player Two card: Ace of Hearts
# Round 139
# Player One card: Two of Hearts, Player Two card: Ten of Clubs
# Round 140
# Player One card: King of Clubs, Player Two card: Seven of Hearts
# Round 141
# Player One card: Nine of Hearts, Player Two card: Three of Hearts
# Round 142
# Player One card: Nine of Diamonds, Player Two card: Ace of Diamonds
# Round 143
# Player One card: Six of Clubs, Player Two card: Six of Diamonds
# WAR!
# Player One card: Ace of Spades, Player Two card: Five of Spades
# Round 144
# Player One card: Jack of Diamonds, Player Two card: Three of Clubs
# Round 145
# Player One card: Queen of Spades, Player Two card: Eight of Spades
# Round 146
# Player One card: Two of Spades, Player Two card: Four of Hearts
# Round 147
# Player One card: Seven of Spades, Player Two card: Ace of Clubs
# Round 148
# Player One card: Six of Hearts, Player Two card: Eight of Hearts
# Round 149
# Player One card: King of Diamonds, Player Two card: King of Hearts
# WAR!
# Player One card: Seven of Hearts, Player Two card: Two of Diamonds
# Round 150
# Player One card: Nine of Hearts, Player Two card: Eight of Diamonds
# Round 151
# Player One card: Three of Hearts, Player Two card: Six of Spades
# Round 152
# Player One card: Six of Clubs, Player Two card: Three of Diamonds
# Round 153
# Player One card: Queen of Diamonds, Player Two card: Two of Clubs
# Round 154
# Player One card: Nine of Spades, Player Two card: King of Spades
# Round 155
# Player One card: Ten of Hearts, Player Two card: Jack of Spades
# Round 156
# Player One card: Eight of Clubs, Player Two card: Queen of Clubs
# Round 157
# Player One card: Ace of Spades, Player Two card: Five of Diamonds
# Round 158
# Player One card: Six of Diamonds, Player Two card: Seven of Diamonds
# Round 159
# Player One card: Seven of Clubs, Player Two card: Three of Spades
# Round 160
# Player One card: Five of Hearts, Player Two card: Ace of Hearts
# Round 161
# Player One card: Nine of Clubs, Player Two card: Jack of Clubs
# Round 162
# Player One card: Four of Diamonds, Player Two card: Ten of Clubs
# Round 163
# Player One card: Five of Spades, Player Two card: Two of Hearts
# Round 164
# Player One card: Jack of Diamonds, Player Two card: Ace of Diamonds
# Round 165
# Player One card: Three of Clubs, Player Two card: Nine of Diamonds
# Round 166
# Player One card: Queen of Spades, Player Two card: Four of Hearts
# Round 167
# Player One card: Eight of Spades, Player Two card: Two of Spades
# Round 168
# Player One card: King of Diamonds, Player Two card: Ace of Clubs
# Round 169
# Player One card: Jack of Hearts, Player Two card: Seven of Spades
# Round 170
# Player One card: Ten of Spades, Player Two card: Eight of Hearts
# Round 171
# Player One card: Four of Spades, Player Two card: Six of Hearts
# Round 172
# Player One card: King of Clubs, Player Two card: Six of Spades
# Round 173
# Player One card: Seven of Hearts, Player Two card: Three of Hearts
# Round 174
# Player One card: King of Hearts, Player Two card: King of Spades
# WAR!
# Player One card: Two of Diamonds, Player Two card: Eight of Clubs
# Round 175
# Player One card: Nine of Hearts, Player Two card: Seven of Diamonds
# Round 176
# Player One card: Eight of Diamonds, Player Two card: Six of Diamonds
# Round 177
# Player One card: Six of Clubs, Player Two card: Ace of Hearts
# Round 178
# Player One card: Three of Diamonds, Player Two card: Five of Hearts
# Round 179
# Player One card: Queen of Diamonds, Player Two card: Jack of Clubs
# Round 180
# Player One card: Two of Clubs, Player Two card: Nine of Clubs
# Round 181
# Player One card: Ace of Spades, Player Two card: Ten of Clubs
# Round 182
# Player One card: Five of Diamonds, Player Two card: Four of Diamonds
# Round 183
# Player One card: Seven of Clubs, Player Two card: Ace of Diamonds
# Round 184
# Player One card: Three of Spades, Player Two card: Jack of Diamonds
# Round 185
# Player One card: Five of Spades, Player Two card: Nine of Diamonds
# Round 186
# Player One card: Two of Hearts, Player Two card: Three of Clubs
# Round 187
# Player One card: Queen of Spades, Player Two card: Ace of Clubs
# Round 188
# Player One card: Four of Hearts, Player Two card: King of Diamonds
# Round 189
# Player One card: Eight of Spades, Player Two card: Six of Hearts
# Round 190
# Player One card: Two of Spades, Player Two card: Four of Spades
# Round 191
# Player One card: Jack of Hearts, Player Two card: King of Spades
# Round 192
# Player One card: Seven of Spades, Player Two card: Nine of Spades
# Round 193
# Player One card: Ten of Spades, Player Two card: Jack of Spades
# Round 194
# Player One card: Eight of Hearts, Player Two card: Ten of Hearts
# Round 195
# Player One card: King of Clubs, Player Two card: Queen of Clubs
# Round 196
# Player One card: Six of Spades, Player Two card: Eight of Clubs
# Round 197
# Player One card: Seven of Hearts, Player Two card: King of Hearts
# Round 198
# Player One card: Three of Hearts, Player Two card: Five of Clubs
# Round 199
# Player One card: Nine of Hearts, Player Two card: Queen of Hearts
# Round 200
# Player One card: Seven of Diamonds, Player Two card: Ten of Diamonds
# Round 201
# Player One card: Eight of Diamonds, Player Two card: Four of Clubs
# Round 202
# Player One card: Six of Diamonds, Player Two card: Two of Diamonds
# Round 203
# Player One card: Queen of Diamonds, Player Two card: Ace of Hearts
# Round 204
# Player One card: Jack of Clubs, Player Two card: Six of Clubs
# Round 205
# Player One card: Ace of Spades, Player Two card: Five of Hearts
# Round 206
# Player One card: Ten of Clubs, Player Two card: Three of Diamonds
# Round 207
# Player One card: Five of Diamonds, Player Two card: Nine of Clubs
# Round 208
# Player One card: Four of Diamonds, Player Two card: Two of Clubs
# Round 209
# Player One card: Eight of Spades, Player Two card: Ace of Diamonds
# Round 210
# Player One card: Six of Hearts, Player Two card: Seven of Clubs
# Round 211
# Player One card: King of Clubs, Player Two card: Jack of Diamonds
# Round 212
# Player One card: Queen of Clubs, Player Two card: Three of Spades
# Round 213
# Player One card: Eight of Diamonds, Player Two card: Nine of Diamonds
# Round 214
# Player One card: Four of Clubs, Player Two card: Five of Spades
# Round 215
# Player One card: Six of Diamonds, Player Two card: Three of Clubs
# Round 216
# Player One card: Two of Diamonds, Player Two card: Two of Hearts
# WAR!
# Player One card: Ten of Clubs, Player Two card: Four of Spades
# Round 217
# Player One card: Three of Diamonds, Player Two card: Two of Spades
# Round 218
# Player One card: Four of Diamonds, Player Two card: King of Spades
# Round 219
# Player One card: Two of Clubs, Player Two card: Jack of Hearts
# Round 220
# Player One card: King of Clubs, Player Two card: Nine of Spades
# Round 221
# Player One card: Jack of Diamonds, Player Two card: Seven of Spades
# Round 222
# Player One card: Queen of Clubs, Player Two card: Jack of Spades
# Round 223
# Player One card: Three of Spades, Player Two card: Ten of Spades
# Round 224
# Player One card: Six of Diamonds, Player Two card: Ten of Hearts
# Round 225
# Player One card: Three of Clubs, Player Two card: Eight of Hearts
# Round 226
# Player One card: Two of Diamonds, Player Two card: Eight of Clubs
# Round 227
# Player One card: Jack of Clubs, Player Two card: Six of Spades
# Round 228
# Player One card: Six of Clubs, Player Two card: King of Hearts
# Round 229
# Player One card: Ace of Spades, Player Two card: Seven of Hearts
# Round 230
# Player One card: Five of Hearts, Player Two card: Five of Clubs
# WAR!
# Player One card: King of Diamonds, Player Two card: Seven of Diamonds
# Round 231
# Player One card: Four of Hearts, Player Two card: Ace of Hearts
# Round 232
# Player One card: Four of Spades, Player Two card: Queen of Diamonds
# Round 233
# Player One card: Three of Diamonds, Player Two card: Nine of Clubs
# Round 234
# Player One card: Two of Spades, Player Two card: Five of Diamonds
# Round 235
# Player One card: King of Clubs, Player Two card: Ace of Diamonds
# Round 236
# Player One card: Nine of Spades, Player Two card: Eight of Spades
# Round 237
# Player One card: Jack of Diamonds, Player Two card: Seven of Clubs
# Round 238
# Player One card: Seven of Spades, Player Two card: Six of Hearts
# Round 239
# Player One card: Queen of Clubs, Player Two card: Nine of Diamonds
# Round 240
# Player One card: Jack of Spades, Player Two card: Eight of Diamonds
# Round 241
# Player One card: Jack of Clubs, Player Two card: Five of Spades
# Round 242
# Player One card: Six of Spades, Player Two card: Four of Clubs
# Round 243
# Player One card: Ace of Spades, Player Two card: King of Spades
# Round 244
# Player One card: Seven of Hearts, Player Two card: Four of Diamonds
# Round 245
# Player One card: Five of Hearts, Player Two card: Jack of Hearts
# Round 246
# Player One card: Ten of Clubs, Player Two card: Two of Clubs
# Round 247
# Player One card: Two of Hearts, Player Two card: Ten of Spades
# Round 248
# Player One card: Ace of Clubs, Player Two card: Three of Spades
# Round 249
# Player One card: Queen of Spades, Player Two card: Ten of Hearts
# Round 250
# Player One card: King of Diamonds, Player Two card: Six of Diamonds
# Round 251
# Player One card: Five of Clubs, Player Two card: Eight of Hearts
# Round 252
# Player One card: Three of Hearts, Player Two card: Three of Clubs
# WAR!
# Player One card: Nine of Spades, Player Two card: Ace of Hearts
# Round 253
# Player One card: Eight of Spades, Player Two card: Four of Hearts
# Round 254
# Player One card: Jack of Diamonds, Player Two card: Queen of Diamonds
# Round 255
# Player One card: Seven of Clubs, Player Two card: Four of Spades
# Round 256
# Player One card: Seven of Spades, Player Two card: Nine of Clubs
# Round 257
# Player One card: Six of Hearts, Player Two card: Three of Diamonds
# Round 258
# Player One card: Queen of Clubs, Player Two card: Five of Diamonds
# Round 259
# Player One card: Nine of Diamonds, Player Two card: Two of Spades
# Round 260
# Player One card: Jack of Spades, Player Two card: Ace of Diamonds
# Round 261
# Player One card: Eight of Diamonds, Player Two card: King of Clubs
# Round 262
# Player One card: Jack of Clubs, Player Two card: Jack of Hearts
# WAR!
# Player One card: King of Spades, Player Two card: Five of Clubs
# Round 263
# Player One card: Seven of Hearts, Player Two card: Three of Clubs
# Round 264
# Player One card: Four of Diamonds, Player Two card: Eight of Clubs
# Round 265
# Player One card: Ten of Clubs, Player Two card: Two of Diamonds
# Round 266
# Player One card: Two of Clubs, Player Two card: King of Hearts
# Round 267
# Player One card: Ace of Clubs, Player Two card: Six of Clubs
# Round 268
# Player One card: Three of Spades, Player Two card: Ace of Hearts
# Round 269
# Player One card: Queen of Spades, Player Two card: Three of Hearts
# Round 270
# Player One card: Ten of Hearts, Player Two card: Queen of Hearts
# Round 271
# Player One card: King of Diamonds, Player Two card: Nine of Hearts
# Round 272
# Player One card: Six of Diamonds, Player Two card: Ten of Diamonds
# Round 273
# Player One card: Eight of Spades, Player Two card: Seven of Diamonds
# Round 274
# Player One card: Four of Hearts, Player Two card: Nine of Spades
# Round 275
# Player One card: Seven of Clubs, Player Two card: Queen of Diamonds
# Round 276
# Player One card: Four of Spades, Player Two card: Jack of Diamonds
# Round 277
# Player One card: Six of Hearts, Player Two card: Nine of Clubs
# Round 278
# Player One card: Three of Diamonds, Player Two card: Seven of Spades
# Round 279
# Player One card: Queen of Clubs, Player Two card: Ace of Diamonds
# Round 280
# Player One card: Five of Diamonds, Player Two card: Jack of Spades
# Round 281
# Player One card: Nine of Diamonds, Player Two card: King of Clubs
# Round 282
# Player One card: Two of Spades, Player Two card: Eight of Diamonds
# Round 283
# Player One card: Jack of Clubs, Player Two card: Eight of Clubs
# Round 284
# Player One card: Five of Spades, Player Two card: Four of Diamonds
# Round 285
# Player One card: Six of Spades, Player Two card: King of Hearts
# Round 286
# Player One card: Four of Clubs, Player Two card: Two of Clubs
# Round 287
# Player One card: Ace of Spades, Player Two card: Ace of Hearts
# WAR!
# Player One card: Two of Hearts, Player Two card: Six of Diamonds
# Round 288
# Player One card: Eight of Hearts, Player Two card: Nine of Spades
# Round 289
# Player One card: Five of Clubs, Player Two card: Four of Hearts
# Round 290
# Player One card: Seven of Hearts, Player Two card: Queen of Diamonds
# Round 291
# Player One card: Three of Clubs, Player Two card: Seven of Clubs
# Round 292
# Player One card: Ten of Clubs, Player Two card: Jack of Diamonds
# Round 293
# Player One card: Two of Diamonds, Player Two card: Four of Spades
# Round 294
# Player One card: Ace of Clubs, Player Two card: Nine of Clubs
# Round 295
# Player One card: Six of Clubs, Player Two card: Six of Hearts
# WAR!
# Player One card: Eight of Spades, Player Two card: Jack of Spades
# Round 296
# Player One card: Seven of Diamonds, Player Two card: Five of Diamonds
# Round 297
# Player One card: Jack of Clubs, Player Two card: King of Clubs
# Round 298
# Player One card: Eight of Clubs, Player Two card: Nine of Diamonds
# Round 299
# Player One card: Five of Spades, Player Two card: Eight of Diamonds
# Round 300
# Player One card: Four of Diamonds, Player Two card: Two of Spades
# Round 301
# Player One card: Four of Clubs, Player Two card: King of Hearts
# Round 302
# Player One card: Two of Clubs, Player Two card: Six of Spades
# Round 303
# Player One card: Five of Clubs, Player Two card: Ace of Hearts
# Round 304
# Player One card: Four of Hearts, Player Two card: Three of Spades
# Round 305
# Player One card: Ace of Clubs, Player Two card: Queen of Hearts
# Round 306
# Player One card: Nine of Clubs, Player Two card: Ten of Hearts
# Round 307
# Player One card: Seven of Diamonds, Player Two card: Ten of Diamonds
# Round 308
# Player One card: Five of Diamonds, Player Two card: Six of Diamonds
# Round 309
# Player One card: Four of Diamonds, Player Two card: Ace of Spades
# Round 310
# Player One card: Two of Spades, Player Two card: King of Spades
# Round 311
# Player One card: Four of Hearts, Player Two card: Jack of Hearts
# Round 312
# Player One card: Three of Spades, Player Two card: Five of Hearts
# Round 313
# Player One card: Ace of Clubs, Player Two card: Ten of Spades
# Round 314
# Player One card: Queen of Hearts, Player Two card: Two of Hearts
# Round 315
# Player One card: Ace of Clubs, Player Two card: Nine of Spades
# Round 316
# Player One card: Ten of Spades, Player Two card: Eight of Hearts
# Round 317
# Player One card: Queen of Hearts, Player Two card: Queen of Diamonds
# WAR!
# Player One card: Eight of Hearts, Player Two card: Ten of Clubs
# Round 318
# Player One Is Out Of Cards, Player Two Wins!
